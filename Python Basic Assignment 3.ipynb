# %% [markdown]
# ### 1. Why are functions advantageous to have in your programs?
# Programs provide reusability of a code. A function can be called to run a set of lines of code as many times as needed instead of writing them every single time.

# %% [markdown]
# ### 2. When does the code in a function run: when it's specified or when it's called?
# Function runs when it is called.

# %% [markdown]
# ### 3. What statement creates a function?
#
# def function_name():

# %% [markdown]
# ### 4. What is the difference between a function and a function call?
#
# Function is a set of statements that need to be executed when that function is called.
# A function call executes the body of the function.

# %% [markdown]
# ### 5. How many global scopes are there in a Python program? How many local scopes?
# There is one global scope. Number of local scopes depends on function definitions. These are separate modules within a program and the scope of variables are local to these function definitions.

# %% [markdown]
# ### 6. What happens to variables in a local scope when the function call returns?
#
# When function call returns, the variables in local scope are removed from memory.

# %% [markdown]
# ### 7.What is the concept of a return value? Is it possible to have a return value in an expression?
# return value is a value that is returned by the function to indicate the end of the function and to instruct to execute the main program.
# A lambda expression can also have a return value.

# %% [markdown]
# ### 8. If a function does not have a return statement, what is the return value of a call to that function?
# Every function returns a value. If no return statement is specified, function returns None value by default.

# %% [markdown]
# ### 9.How do you make a function variable refer to the global variable?
#
# A global keyword has to be used to indicate to the function that the variable refers to the global one.

# %% [markdown]
# ### 10. What is the data type of None?
# It belongs to None type.

# %% [markdown]
# ### 11. What does the sentence import areallyourpetsnamederic do?
#
# It will throw an error unless we have a module named areallyourpetsnamederic in our working directory. If we have such a module, then it will be imported.

# %% [markdown]
# ### 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# spam.bacon()

# %% [markdown]
# ### 13. What can you do to save a programme from crashing if it encounters an error?
# We can utilize exception handling to prevent the program from crashing when error is encountered.

# %% [markdown]
# ### 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# try clause is used to run the code that we want to protect against any run-time error. Except clause has the set of code that will run if a run-time error is encountered in the try block.
