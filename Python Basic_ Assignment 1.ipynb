# %% [raw]
# Question 1- In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
#
# *    ---->  Expression
# 'hello'--->  Value
# -87.8  ---> Value
# -   ----> Expression
# /   ----> Expression
# +	-----> Expression
# 6   -----> Expression

# %% [raw]
# Question 2- What is the difference between string and variable?
#
# A string is a text which belongs to string (str) type.
# A variable can be a store of information in any form of data type- string, integer, list etc.,

# %% [raw]
# Question 3- Describe three different data types.
#
# Integer, String, list.
#
# Integer(int) stores data type of integer type- 1,2,3 etc.,
# string(str) stores text string- "ineuron", "fsds"
# list (list) stores a collection of mutable, ordered sequence of items- [1,2,3,'Nithin']

# %% [raw]
# Question 4- What is an expression made up of? What do all expressions do?
#
# Expression is a combination of variables or operators or function calls. Expressions basically evaluate to some value.

# %% [raw]
# Question 5- This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# In an assignment statement, the value on the right side of equal to is assigned to the variable on the left. In the above, spam is assigned a value of 10.
#
# Expression is a type of statement that evaluates to some return value.

# %% [raw]
# Question 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# bacon variable now contains 23.

# %% [raw]
# Question 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Both of the above evaluate to 'spamspamspam'

# %% [raw]
# Question 8. Why is eggs a valid variable name while 100 is invalid?
#
# Variables in python can only start with underscore or alphabet. Hence, 100 is an invalid variable name.

# %% [raw]
# Question 9 What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# int(), float(), str()

# %% [raw]
# Question 10. Why does this expression cause an error? How can you fix it?
#
# 'I have eaten ' + 99 + ' burritos.'

# %% [raw]
# Convert 99 into string to do the concatenation
# 'I have eaten ' + str(99) + ' burritos'
