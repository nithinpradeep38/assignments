# %% [markdown]
# Q1. What is the purpose of Python's OOP?

# %% [markdown]
# OOP helps break down code in modules which makes it easier to work on big projects and maintain big chunks of code. It also helps implement re-usability of code.

# %% [markdown]
# Q2. Where does an inheritance search look for an attribute?

# %% [markdown]
# Inheritance looks first at the sub-class under which the object is instantiated. Then it moves to the super-class.

# %% [markdown]
# Q3. How do you distinguish between a class object and an instance object?

# %% [markdown]
# Class object is created every time a class is defined, even if we don't create an instance variable.
# If we have a class definition with a static variables, we will be able to access these variables through the notation "classname.variablename" without even defining an instance variable.
#
# Instance objects are created every time an instance is defined under a class. We may initilise these instance object through an __init__ constructor. The class variables initialized in such a way maybe called as "instancename.variablename".

# %% [markdown]
# Q4. What makes the first argument in a class’s method function special?

# %% [markdown]
# The first argument is an implicitly passes argument, which is a pointer that represents the instance object itself.

# %% [markdown]
# Q5.What is the purpose of the __init__ method?

# %% [markdown]
# init is a constructor which takes in the arguments and initializes the class variables when we create an instance object.

# %% [markdown]
# Q6.What is the process for creating a class instance?

# %% [markdown]
# instance_name= class_name(class variables)
#
# For example,
# x= abc(1,2) initializes an instance x under class abc with class variables assigned 1 & 2 respectively.

# %% [markdown]
# Q7.What is the process for creating a class?

# %%
class class_name:
    def __init__(self,a,b):  #for initializing class variables
        self.a=a        #initializing the class variable self.a and self.b with arguments passed at time of creating instance
        self.b=b
    def classfunc(self):  #defining a method inside a class. self is a 
        print(a,b)

# %% [markdown]
# Q8. How would you define the superclasses of a class?

# %% [markdown]
# The class from which a sub-class inherits is called a superclass. In the below example, parent is a super class to the sub-class child.
#
# class parent:
#
#     pass
#
# class child(parent):
#
#     pass
