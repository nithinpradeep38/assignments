# %% [markdown]
# 1. What are escape characters, and how do you use them?

# %% [raw]
# They are special characters used for some purpose. For example, \ is a special character if we want a single quote inside a string.
# For example, to print python's in a string in single quote, we have to use the escape character as following.
#
# print('python\'s')
#
# Similarly, there are special characters for white spaces. \r for carriage return, \n for new line.

# %% [markdown]
# 2. What do the escape characters n and t stand for?

# %% [raw]
# n is the escape character for a new line, whereas t is for new tab.

# %% [markdown]
# 3. What is the way to include backslash characters in a string?

# %%
#By using the backlash escape character
print("Add \\ here")
# Out:
# Add \ here

# %% [markdown]
# 4. The string "Howl's Moving Castle" is a correct value. Why isn't the single quote character in the word Howl's not escaped a problem?

# %% [raw]
# If we enclose the text Howl's Moving Castle in double quotes, we will not encounter an issue.
# But if we enclose in single quotes, then we have to use the escape character for single quote and use 'Howl\'s Moving Castle'

# %%
'Howl\'s Moving Castle'
# Out:
# "Howl's Moving Castle"

# %%
"Howl's Moving Castle"
# Out:
# "Howl's Moving Castle"

# %% [markdown]
# 5. How do you write a string of newlines if you don't want to use the n character?

# %%
We can use the linesep
import os
text= 'line1' + os.linesep  + 'line2'
print(text)
# Out:
# line1
# line2

# %% [markdown]
# 6. What are the values of the given expressions?

# %% [raw]
# 'Hello, world!'[1]---> 'e'
# 'Hello, world!'[0:5]--> 'Hello'
# 'Hello, world!'[:5]--> 'Hello'
# 'Hello, world!'[3:]--> 'lo, world!'

# %% [markdown]
# 7. What are the values of the following expressions?

# %% [raw]
# 'Hello'.upper() --> 'HELLO'
# 'Hello'.upper().isupper()--> True
# 'Hello'.upper().lower()--> 'hello'

# %% [markdown]
# 8. What are the values of the following expressions?

# %%
'Remember, remember, the fifth of July.'.split()
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']

# %%
'-'.join('There can only one.'.split())
# Out:
# 'There-can-only-one.'

# %% [markdown]
# 9. What are the methods for right-justifying, left-justifying, and centering a string?

# %% [raw]
# right justifying--> stringname.rjust(width, fillchar )
# left justifying--> stringname.ljust(width, fillchar)
# centering--> stringname.center(width, fillchar)

# %% [markdown]
# 10. What is the best way to remove whitespace characters from the start or end?

# %% [raw]
# We can remove all whitespace characters by using the strip function.
# stringname.strip()
